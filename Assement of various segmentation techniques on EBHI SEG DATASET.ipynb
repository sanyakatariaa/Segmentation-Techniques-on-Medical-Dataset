# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import ResNet50, MobileNetV2, EfficientNetB0, DenseNet121
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
# Update the dataset path as per Kaggle environment
DATASET_PATH = "/kaggle/input/ebhi-seg/EBHI-SEG"  

# Define all categories present in the dataset
CATEGORIES = ['Adenocarcinoma', 'High-grade IN', 'Low-grade IN', 'Normal', 'Polyp', 'Serrated adenoma']

IMG_HEIGHT, IMG_WIDTH = 224, 224  # Standard input size for deep learning models
NUM_CLASSES = 2  # Binary Segmentation (Cancer vs. Non-Cancer)

# %%
def load_dataset(dataset_path, categories):
    images, masks = [], []

    for category in categories:
        image_dir = os.path.join(dataset_path, category, "image")
        mask_dir = os.path.join(dataset_path, category, "label")

        image_files = sorted(os.listdir(image_dir))
        mask_files = sorted(os.listdir(mask_dir))

        for img_name, mask_name in zip(image_files, mask_files):
            img_path = os.path.join(image_dir, img_name)
            mask_path = os.path.join(mask_dir, mask_name)

            img = load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
            mask = load_img(mask_path, target_size=(IMG_HEIGHT, IMG_WIDTH), color_mode="grayscale")

            img = img_to_array(img) / 255.0  # Normalize image
            mask = img_to_array(mask) / 255.0  # Normalize mask
            mask = np.where(mask > 0.5, 1, 0)  # Convert to binary mask

            images.append(img)
            masks.append(mask)

    return np.array(images), np.array(masks)

images, masks = load_dataset(DATASET_PATH, CATEGORIES)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(images, masks, test_size=0.2, random_state=42)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=42)

print("Training:", X_train.shape, Y_train.shape)
print("Validation:", X_val.shape, Y_val.shape)
print("Testing:", X_test.shape, Y_test.shape)
# Out:
# Training: (1602, 224, 224, 3) (1602, 224, 224, 1)
# Validation: (178, 224, 224, 3) (178, 224, 224, 1)
# Testing: (446, 224, 224, 3) (446, 224, 224, 1)

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
])

# %%
import os

AUGMENTED_PATH = "/kaggle/working/augmented_ebhi_seg"  # Define a path to save augmented data

# Create the main directory if not exists
os.makedirs(AUGMENTED_PATH, exist_ok=True)

# Create subdirectories for each category
for category in CATEGORIES:
    os.makedirs(os.path.join(AUGMENTED_PATH, category, "images"), exist_ok=True)
    os.makedirs(os.path.join(AUGMENTED_PATH, category, "masks"), exist_ok=True)

print("Folders created successfully!")
# Out:
# Folders created successfully!

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img

# Define augmentation techniques
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode="nearest"
)

def augment_and_save(images, masks, category, num_augments=2):
    """
    Perform data augmentation and save images and masks to new files.

    Parameters:
        images (numpy array): Input images (batch_size, 224, 224, 3)
        masks (numpy array): Corresponding masks (batch_size, 224, 224, 1)
        category (str): Category name (e.g., 'Adenocarcinoma')
        num_augments (int): Number of augmented images to generate per image
    """
    for i in range(len(images)):
        img = images[i]
        mask = masks[i]
        
        # Expand dims to create batch dimension (1, 224, 224, 3) and (1, 224, 224, 1)
        img = np.expand_dims(img, axis=0)  
        mask = np.expand_dims(mask, axis=0)  

        # Ensure mask dtype is compatible (convert float64 to uint8)
        mask = mask.astype(np.uint8)

        img_gen = datagen.flow(img, batch_size=1, save_prefix="image", save_format="png")
        mask_gen = datagen.flow(mask, batch_size=1, save_prefix="mask", save_format="png")

        for j in range(num_augments):
            aug_img = next(img_gen)[0]  # Convert to 3D
            aug_mask = next(mask_gen)[0]  # Convert to 3D

            # Ensure correct save paths
            img_filename = os.path.join(AUGMENTED_PATH, category, "images", f"aug_{i}_{j}.png")
            mask_filename = os.path.join(AUGMENTED_PATH, category, "masks", f"aug_{i}_{j}.png")

            # Convert arrays to image format and save
            array_to_img(aug_img).save(img_filename)
            array_to_img(aug_mask).save(mask_filename)

        # Save original image and mask as well
        original_img_filename = os.path.join(AUGMENTED_PATH, category, "images", f"original_{i}.png")
        original_mask_filename = os.path.join(AUGMENTED_PATH, category, "masks", f"original_{i}.png")

        array_to_img(images[i]).save(original_img_filename)
        array_to_img(masks[i]).save(original_mask_filename)

    print(f"Augmented data saved for {category}")

# %%
for category in CATEGORIES:
    print(f"Processing category: {category}")
    
    # Load dataset for this specific category
    images, masks = load_dataset(DATASET_PATH, [category])
    
    # Augment and save
    augment_and_save(images, masks, category, num_augments=2)  # Generates 2 new images per original
# Out:
# Processing category: Adenocarcinoma
# Augmented data saved for Adenocarcinoma
# Processing category: High-grade IN
# Augmented data saved for High-grade IN
# Processing category: Low-grade IN
# Augmented data saved for Low-grade IN
# Processing category: Normal
# Augmented data saved for Normal
# Processing category: Polyp
# Augmented data saved for Polyp
# Processing category: Serrated adenoma
# Augmented data saved for Serrated adenoma

# %%
import os

# List the number of saved images in a category
category_to_check = "Normal"

num_images = len(os.listdir(os.path.join(AUGMENTED_PATH, category_to_check, "images")))
num_masks = len(os.listdir(os.path.join(AUGMENTED_PATH, category_to_check, "masks")))

print(f"Saved {num_images} images and {num_masks} masks for category {category_to_check}")
# Out:
# Saved 228 images and 228 masks for category Normal

# %%
def build_unet(input_shape=(IMG_HEIGHT, IMG_WIDTH, 3), num_classes=NUM_CLASSES):
    inputs = keras.Input(shape=input_shape)

    # Encoder
    conv1 = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(inputs)
    conv1 = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(conv1)
    pool1 = layers.MaxPooling2D((2, 2))(conv1)

    conv2 = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(pool1)
    conv2 = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(conv2)
    pool2 = layers.MaxPooling2D((2, 2))(conv2)

    conv3 = layers.Conv2D(256, (3, 3), activation="relu", padding="same")(pool2)
    conv3 = layers.Conv2D(256, (3, 3), activation="relu", padding="same")(conv3)
    pool3 = layers.MaxPooling2D((2, 2))(conv3)

    # Bottleneck
    conv4 = layers.Conv2D(512, (3, 3), activation="relu", padding="same")(pool3)
    conv4 = layers.Conv2D(512, (3, 3), activation="relu", padding="same")(conv4)

  # Decoder: FULLY UPSAMPLING BACK TO (224, 224, 1)
    up5 = layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(conv4)  # (56, 56)
    up5 = layers.concatenate([up5, conv3])
    conv5 = layers.Conv2D(256, (3, 3), activation="relu", padding="same")(up5)

    up6 = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(conv5)  # (112, 112)
    up6 = layers.concatenate([up6, conv2])
    conv6 = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(up6)

    up7 = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(conv6)  # (224, 224)
    up7 = layers.concatenate([up7, conv1])
    conv7 = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(up7)

    outputs = layers.Conv2D(1, (1, 1), activation="sigmoid", padding="same")(conv7)  # Ensure (224, 224, 1)

    return keras.Model(inputs, outputs)

unet_model = build_unet()

# %%
def build_unet_backbone(base_model, input_shape=(224, 224, 3)):
    inputs = keras.Input(shape=input_shape)

    # Load base model WITHOUT top layers
    base = base_model(input_tensor=inputs, include_top=False, weights=None)  

    # Extract last feature map
    x = base.output  # Default shape is typically (7,7,C) or (14,14,C)

    # Decoder: Force Upsampling to (224, 224, 1)
    x = layers.Conv2DTranspose(512, (3, 3), strides=(2, 2), padding="same")(x)  # (14, 14)
    x = layers.Conv2D(256, (3, 3), activation="relu", padding="same")(x)

    x = layers.Conv2DTranspose(256, (3, 3), strides=(2, 2), padding="same")(x)  # (28, 28)
    x = layers.Conv2D(128, (3, 3), activation="relu", padding="same")(x)

    x = layers.Conv2DTranspose(128, (3, 3), strides=(2, 2), padding="same")(x)  # (56, 56)
    x = layers.Conv2D(64, (3, 3), activation="relu", padding="same")(x)

    x = layers.Conv2DTranspose(64, (3, 3), strides=(2, 2), padding="same")(x)  # (112, 112)
    x = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(x)

    x = layers.Conv2DTranspose(32, (3, 3), strides=(2, 2), padding="same")(x)  # (224, 224)
    x = layers.Conv2D(16, (3, 3), activation="relu", padding="same")(x)

    outputs = layers.Conv2D(1, (1, 1), activation="sigmoid", padding="same")(x)  # (224, 224, 1)

    return keras.Model(inputs, outputs)

# %%
try:
    print(resnet_unet.summary())
    print(mobilenet_unet.summary())
    print(efficientnet_unet.summary())
    print(densenet_unet.summary())
except NameError as e:
    print("Error:", e)
# Out:
# Error: name 'resnet_unet' is not defined

# %%
# Define U-Net with ResNet50 Backbone
resnet_unet = build_unet_backbone(ResNet50)

# Define U-Net with MobileNetV2 Backbone
mobilenet_unet = build_unet_backbone(MobileNetV2)

# Define U-Net with EfficientNetB0 Backbone
efficientnet_unet = build_unet_backbone(EfficientNetB0)

# Define U-Net with DenseNet121 Backbone
densenet_unet = build_unet_backbone(DenseNet121)

# %%
print("U-Net Output Shape:", unet_model.output_shape)
print("ResNet50 U-Net Output Shape:", resnet_unet.output_shape)
print("MobileNetV2 U-Net Output Shape:", mobilenet_unet.output_shape)
print("EfficientNetB0 U-Net Output Shape:", efficientnet_unet.output_shape)
print("DenseNet121 U-Net Output Shape:", densenet_unet.output_shape)
# Out:
# U-Net Output Shape: (None, 224, 224, 1)
# ResNet50 U-Net Output Shape: (None, 224, 224, 1)
# MobileNetV2 U-Net Output Shape: (None, 224, 224, 1)
# EfficientNetB0 U-Net Output Shape: (None, 224, 224, 1)
# DenseNet121 U-Net Output Shape: (None, 224, 224, 1)

# %%
def compile_and_train(model, name):
    # ✅ Use AdamW instead of Adam for better stability
    optimizer = tf.keras.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-4)

    model.compile(optimizer=optimizer, loss="binary_crossentropy", metrics=["accuracy"])

    # ✅ Increase patience for early stopping (to 20 epochs)
    early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

    # ✅ Reduce LR decay sensitivity (factor=0.7, min_lr=1e-7)
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.7, patience=5, min_lr=1e-7)

    history = model.fit(
        X_train, Y_train, validation_data=(X_val, Y_val),
        batch_size=32,  # ✅ Increase batch size for better gradient updates
        epochs=100,  # ✅ Allow more epochs
        callbacks=[early_stopping, reduce_lr]
    )

    model.save(f"{name}.h5")
    return history

# %%
histories = {
    "U-Net": compile_and_train(unet_model, "unet"),
    "ResNet50 U-Net": compile_and_train(resnet_unet, "resnet_unet"),
    "MobileNet U-Net": compile_and_train(mobilenet_unet, "mobilenet_unet"),
    "EfficientNet U-Net": compile_and_train(efficientnet_unet, "efficientnet_unet"),
    "DenseNet U-Net": compile_and_train(densenet_unet, "densenet_unet"),
}
# Out:
# Epoch 1/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 91s 995ms/step - accuracy: 0.6335 - loss: 0.6473 - val_accuracy: 0.6915 - val_loss: 0.5874 - learning_rate: 0.0010
# Epoch 2/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - accuracy: 0.6858 - loss: 0.5888 - val_accuracy: 0.7043 - val_loss: 0.5808 - learning_rate: 0.0010
# Epoch 3/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 410ms/step - accuracy: 0.6986 - loss: 0.5783 - val_accuracy: 0.6388 - val_loss: 0.6194 - learning_rate: 0.0010
# Epoch 4/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - accuracy: 0.6911 - loss: 0.6329 - val_accuracy: 0.6638 - val_loss: 0.6232 - learning_rate: 0.0010
# Epoch 5/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - accuracy: 0.6577 - loss: 0.6135 - val_accuracy: 0.6820 - val_loss: 0.6060 - learning_rate: 0.0010
# Epoch 6/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 408ms/step - accuracy: 0.6754 - loss: 0.6169 - val_accuracy: 0.6399 - val_loss: 0.7319 - learning_rate: 0.0010
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - accuracy: 0.6217 - loss: 0.6778 - val_accuracy: 0.6395 - val_loss: 0.6489 - learning_rate: 0.0010
# Epoch 8/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 409ms/step - accuracy: 0.6286 - loss: 0.6495 - val_accuracy: 0.6399 - val_loss: 0.6228 - learning_rate: 7.0000e-04
# Epoch 9/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 408ms/step - accuracy: 0.6457 - loss: 0.6209 - val_accuracy: 0.6505 - val_loss: 0.6174 - learning_rate: 7.0000e-04
# Epoch 10/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 408ms/step - accuracy: 0
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.7732 - loss: 0.5147 - val_accuracy: 0.6392 - val_loss: 0.6472 - learning_rate: 0.0010
# Epoch 8/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.7597 - loss: 0.5052 - val_accuracy: 0.6395 - val_loss: 0.7535 - learning_rate: 0.0010
# Epoch 9/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.7836 - loss: 0.4587 - val_accuracy: 0.6395 - val_loss: 0.7018 - learning_rate: 0.0010
# Epoch 10/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.7803 - loss: 0.4688 - val_accuracy: 0.6396 - val_loss: 0.7768 - learning_rate: 0.0010
# Epoch 11/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.8008 - loss: 0.4312 - val_accuracy: 0.6396 - val_loss: 0.7337 - learning_rate: 0.0010
# Epoch 12/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.8089 - loss: 0.4153 - val_accuracy: 0.6396 - val_loss: 0.9488 - learning_rate: 0.0010
# Epoch 13/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.8183 - loss: 0.3879 - val_accuracy: 0.6395 - val_loss: 0.7499 - learning_rate: 7.0000e-04
# Epoch 14/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.8294 - loss: 0.3627 - val_accuracy: 0.6396 - val_loss: 0.9417 - learning_rate: 7.0000e-04
# Epoch 15/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.8342 - loss: 0.3499 - val_accuracy: 0.6396 - val_loss: 0.9494 - learning_rate: 7.0000e-04
# Epoch 16/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.8146 - loss: 0.3978 - val_accuracy: 0.6396 - val_loss: 0.8644 - learning_rate: 7.0000e-04
# Epoch 17/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.8376 - loss: 0.3391 - val_accuracy: 0.6396 - val_loss: 1.0089 - learning_rate: 7.0000e-04
# Epoch 18/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.8426 - loss: 0.3250 - val_accuracy: 0.6396 - val_loss: 1.0047 - learning_rate: 4.9000e-04
# Epoch 19/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.8306 - loss: 0.3691 - val_accuracy: 0.6396 - val_loss: 1.0985 - learning_rate: 4.9000e-04
# Epoch 20/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.8541 - loss: 0.3109 - val_accuracy: 0.6396 - val_loss: 0.9913 - learning_rate: 4.9000e-04
# Epoch 21/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.8486 - loss: 0.3222 - val_accuracy: 0.6396 - val_loss: 1.3382 - learning_rate: 4.9000e-04
# Epoch 22/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.8564 - loss: 0.3001 - val_accuracy: 0.6396 - val_loss: 1.1734 - learning_rate: 4.9000e-04
# Epoch 23/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.8645 - loss: 0.2906 - val_accuracy: 0.6396 - val_loss: 1.3636 - learning_rate: 3.4300e-04
# Epoch 24/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.8772 - loss: 0.2675 - val_accuracy: 0.6396 - val_loss: 1.2970 - learning_rate: 3.4300e-04
# Epoch 25/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.8828 - loss: 0.2594 - val_accuracy: 0.6396 - val_loss: 1.8933 - learning_rate: 3.4300e-04
# Epoch 26/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.8805 - loss: 0.2608 - val_accuracy: 0.6396 - val_loss: 1.6389 - learning_rate: 3.4300e-04
# Epoch 27/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.8729 - loss: 0.2846 - val_accuracy: 0.6396 - val_loss: 1.3960 - learning_rate: 3.4300e-04
# Epoch 1/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 127s 1s/step - accuracy: 0.6229 - loss: 0.6871 - val_accuracy: 0.6396 - val_loss: 0.6567 - learning_rate: 0.0010
# Epoch 2/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.6397 - loss: 0.6298 - val_accuracy: 0.6396 - val_loss: 0.6661 - learning_rate: 0.0010
# Epoch 3/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.6326 - loss: 0.6126 - val_accuracy: 0.6396 - val_loss: 0.6826 - learning_rate: 0.0010
# Epoch 4/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.6634 - loss: 0.5725 - val_accuracy: 0.6272 - val_loss: 0.6726 - learning_rate: 0.0010
# Epoch 5/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.7346 - loss: 0.5512 - val_accuracy: 0.6397 - val_loss: 0.7186 - learning_rate: 0.0010
# Epoch 6/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.7562 - loss: 0.5073 - val_accuracy: 0.6396 - val_loss: 0.9517 - learning_rate: 0.0010
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.7796 - loss: 0.4778 - val_accuracy: 0.6113 - val_loss: 0.8645 - learning_rate: 7.0000e-04
# Epoch 8/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.7986 - loss: 0.4430 - val_accuracy: 0.6130 - val_loss: 0.8918 - learning_rate: 7.0000e-04
# Epoch 9/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.8166 - loss: 0.4071 - val_accuracy: 0.6345 - val_loss: 0.8360 - learning_rate: 7.0000e-04
# Epoch 10/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8203 - loss: 0.3983 - val_accuracy: 0.6088 - val_loss: 0.7930 - learning_rate: 7.0000e-04
# Epoch 11/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8180 - loss: 0.4048 - val_accuracy: 0.6460 - val_loss: 0.7845 - learning_rate: 7.0000e-04
# Epoch 12/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8416 - loss: 0.3525 - val_accuracy: 0.6522 - val_loss: 0.7885 - learning_rate: 4.9000e-04
# Epoch 13/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8488 - loss: 0.3392 - val_accuracy: 0.6806 - val_loss: 0.6713 - learning_rate: 4.9000e-04
# Epoch 14/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.8605 - loss: 0.3138 - val_accuracy: 0.7104 - val_loss: 0.7393 - learning_rate: 4.9000e-04
# Epoch 15/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.8638 - loss: 0.3083 - val_accuracy: 0.7274 - val_loss: 0.6289 - learning_rate: 4.9000e-04
# Epoch 16/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.8608 - loss: 0.3181 - val_accuracy: 0.7413 - val_loss: 0.6182 - learning_rate: 4.9000e-04
# Epoch 17/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.8705 - loss: 0.2955 - val_accuracy: 0.7263 - val_loss: 0.6005 - learning_rate: 4.9000e-04
# Epoch 18/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8758 - loss: 0.2847 - val_accuracy: 0.7470 - val_loss: 0.6015 - learning_rate: 4.9000e-04
# Epoch 19/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8712 - loss: 0.2961 - val_accuracy: 0.7527 - val_loss: 0.6296 - learning_rate: 4.9000e-04
# Epoch 20/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 200ms/step - accuracy: 0.8764 - loss: 0.2858 - val_accuracy: 0.7374 - val_loss: 0.5517 - learning_rate: 4.9000e-04
# Epoch 21/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8687 - loss: 0.3065 - val_accuracy: 0.7479 - val_loss: 0.6224 - learning_rate: 4.9000e-04
# Epoch 22/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8841 - loss: 0.2663 - val_accuracy: 0.7368 - val_loss: 0.6350 - learning_rate: 4.9000e-04
# Epoch 23/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8887 - loss: 0.2577 - val_accuracy: 0.7481 - val_loss: 0.6504 - learning_rate: 4.9000e-04
# Epoch 24/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.8935 - loss: 0.2468 - val_accuracy: 0.7366 - val_loss: 0.6323 - learning_rate: 4.9000e-04
# Epoch 25/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 197ms/step - accuracy: 0.8913 - loss: 0.2506 - val_accuracy: 0.7432 - val_loss: 0.6770 - learning_rate: 4.9000e-04
# Epoch 26/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.8913 - loss: 0.2501 - val_accuracy: 0.7511 - val_loss: 0.6885 - learning_rate: 3.4300e-04
# Epoch 27/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9009 - loss: 0.2285 - val_accuracy: 0.7341 - val_loss: 0.6521 - learning_rate: 3.4300e-04
# Epoch 28/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9023 - loss: 0.2287 - val_accuracy: 0.7349 - val_loss: 0.6729 - learning_rate: 3.4300e-04
# Epoch 29/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9055 - loss: 0.2191 - val_accuracy: 0.7398 - val_loss: 0.6455 - learning_rate: 3.4300e-04
# Epoch 30/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9081 - loss: 0.2139 - val_accuracy: 0.7535 - val_loss: 0.7031 - learning_rate: 3.4300e-04
# Epoch 31/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9084 - loss: 0.2113 - val_accuracy: 0.7511 - val_loss: 0.6854 - learning_rate: 2.4010e-04
# Epoch 32/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9085 - loss: 0.2115 - val_accuracy: 0.7458 - val_loss: 0.6702 - learning_rate: 2.4010e-04
# Epoch 33/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9155 - loss: 0.1965 - val_accuracy: 0.7435 - val_loss: 0.6455 - learning_rate: 2.4010e-04
# Epoch 34/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9090 - loss: 0.2134 - val_accuracy: 0.7424 - val_loss: 0.6687 - learning_rate: 2.4010e-04
# Epoch 35/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9107 - loss: 0.2057 - val_accuracy: 0.7470 - val_loss: 0.6962 - learning_rate: 2.4010e-04
# Epoch 36/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9180 - loss: 0.1905 - val_accuracy: 0.7461 - val_loss: 0.6879 - learning_rate: 1.6807e-04
# Epoch 37/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9173 - loss: 0.1916 - val_accuracy: 0.7379 - val_loss: 0.6910 - learning_rate: 1.6807e-04
# Epoch 38/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 198ms/step - accuracy: 0.9176 - loss: 0.1908 - val_accuracy: 0.7485 - val_loss: 0.7243 - learning_rate: 1.6807e-04
# Epoch 39/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9179 - loss: 0.1913 - val_accuracy: 0.7496 - val_loss: 0.7136 - learning_rate: 1.6807e-04
# Epoch 40/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.9216 - loss: 0.1812 - val_accuracy: 0.7490 - val_loss: 0.7293 - learning_rate: 1.6807e-04
# Epoch 1/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 305s 3s/step - accuracy: 0.6174 - loss: 0.6922 - val_accuracy: 0.6395 - val_loss: 1.8254 - learning_rate: 0.0010
# Epoch 2/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.6514 - loss: 0.5920 - val_accuracy: 0.6396 - val_loss: 2.5833 - learning_rate: 0.0010
# Epoch 3/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 268ms/step - accuracy: 0.7215 - loss: 0.5765 - val_accuracy: 0.6396 - val_loss: 0.6522 - learning_rate: 0.0010
# Epoch 4/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.7540 - loss: 0.5293 - val_accuracy: 0.6612 - val_loss: 0.8843 - learning_rate: 0.0010
# Epoch 5/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.7781 - loss: 0.4881 - val_accuracy: 0.6396 - val_loss: 2.4895 - learning_rate: 0.0010
# Epoch 6/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.7856 - loss: 0.4716 - val_accuracy: 0.6672 - val_loss: 1.3351 - learning_rate: 0.0010
# Epoch 7/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.7838 - loss: 0.4800 - val_accuracy: 0.6824 - val_loss: 0.7491 - learning_rate: 0.0010
# Epoch 8/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 269ms/step - accuracy: 0.7961 - loss: 0.4499 - val_accuracy: 0.6705 - val_loss: 0.6318 - learning_rate: 0.0010
# Epoch 9/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.7860 - loss: 0.4863 - val_accuracy: 0.6877 - val_loss: 0.5784 - learning_rate: 0.0010
# Epoch 10/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 269ms/step - accuracy: 0.7759 - loss: 0.4773 - val_accuracy: 0.7544 - val_loss: 0.5606 - learning_rate: 0.0010
# Epoch 11/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8005 - loss: 0.4327 - val_accuracy: 0.6816 - val_loss: 0.6008 - learning_rate: 0.0010
# Epoch 12/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8051 - loss: 0.4396 - val_accuracy: 0.6625 - val_loss: 0.6250 - learning_rate: 0.0010
# Epoch 13/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.8031 - loss: 0.4258 - val_accuracy: 0.8027 - val_loss: 0.4145 - learning_rate: 0.0010
# Epoch 14/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8085 - loss: 0.4167 - val_accuracy: 0.7671 - val_loss: 0.5214 - learning_rate: 0.0010
# Epoch 15/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.7901 - loss: 0.4564 - val_accuracy: 0.6656 - val_loss: 0.5996 - learning_rate: 0.0010
# Epoch 16/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8235 - loss: 0.3925 - val_accuracy: 0.7941 - val_loss: 0.4584 - learning_rate: 0.0010
# Epoch 17/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.8259 - loss: 0.3779 - val_accuracy: 0.7581 - val_loss: 0.5102 - learning_rate: 0.0010
# Epoch 18/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.8257 - loss: 0.3752 - val_accuracy: 0.7936 - val_loss: 0.4637 - learning_rate: 0.0010
# Epoch 19/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8282 - loss: 0.3722 - val_accuracy: 0.8091 - val_loss: 0.4324 - learning_rate: 7.0000e-04
# Epoch 20/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 268ms/step - accuracy: 0.8445 - loss: 0.3361 - val_accuracy: 0.8151 - val_loss: 0.3968 - learning_rate: 7.0000e-04
# Epoch 21/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8441 - loss: 0.3327 - val_accuracy: 0.7935 - val_loss: 0.4378 - learning_rate: 7.0000e-04
# Epoch 22/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8155 - loss: 0.3926 - val_accuracy: 0.8127 - val_loss: 0.4373 - learning_rate: 7.0000e-04
# Epoch 23/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8493 - loss: 0.3229 - val_accuracy: 0.7832 - val_loss: 0.4619 - learning_rate: 7.0000e-04
# Epoch 24/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.8431 - loss: 0.3296 - val_accuracy: 0.8167 - val_loss: 0.3944 - learning_rate: 7.0000e-04
# Epoch 25/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8510 - loss: 0.3161 - val_accuracy: 0.8134 - val_loss: 0.4222 - learning_rate: 7.0000e-04
# Epoch 26/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8401 - loss: 0.3362 - val_accuracy: 0.8136 - val_loss: 0.5155 - learning_rate: 7.0000e-04
# Epoch 27/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8418 - loss: 0.3333 - val_accuracy: 0.8122 - val_loss: 0.4087 - learning_rate: 7.0000e-04
# Epoch 28/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.8488 - loss: 0.3098 - val_accuracy: 0.8120 - val_loss: 0.4820 - learning_rate: 7.0000e-04
# Epoch 29/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8521 - loss: 0.3080 - val_accuracy: 0.8012 - val_loss: 0.4366 - learning_rate: 7.0000e-04
# Epoch 30/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8593 - loss: 0.2914 - val_accuracy: 0.8097 - val_loss: 0.4457 - learning_rate: 4.9000e-04
# Epoch 31/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 270ms/step - accuracy: 0.8586 - loss: 0.2898 - val_accuracy: 0.8195 - val_loss: 0.3848 - learning_rate: 4.9000e-04
# Epoch 32/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8639 - loss: 0.2815 - val_accuracy: 0.8186 - val_loss: 0.4002 - learning_rate: 4.9000e-04
# Epoch 33/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8628 - loss: 0.2875 - val_accuracy: 0.8033 - val_loss: 0.4338 - learning_rate: 4.9000e-04
# Epoch 34/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 264ms/step - accuracy: 0.8623 - loss: 0.2853 - val_accuracy: 0.8189 - val_loss: 0.3858 - learning_rate: 4.9000e-04
# Epoch 35/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.8674 - loss: 0.2720 - val_accuracy: 0.8132 - val_loss: 0.3931 - learning_rate: 4.9000e-04
# Epoch 36/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8507 - loss: 0.3294 - val_accuracy: 0.8125 - val_loss: 0.4152 - learning_rate: 4.9000e-04
# Epoch 37/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.8661 - loss: 0.2778 - val_accuracy: 0.8197 - val_loss: 0.4234 - learning_rate: 3.4300e-04
# Epoch 38/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8682 - loss: 0.2713 - val_accuracy: 0.8137 - val_loss: 0.4289 - learning_rate: 3.4300e-04
# Epoch 39/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.8568 - loss: 0.3102 - val_accuracy: 0.8225 - val_loss: 0.3880 - learning_rate: 3.4300e-04
# Epoch 40/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.8686 - loss: 0.2717 - val_accuracy: 0.8184 - val_loss: 0.4454 - learning_rate: 3.4300e-04
# Epoch 41/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8745 - loss: 0.2648 - val_accuracy: 0.8082 - val_loss: 0.4166 - learning_rate: 3.4300e-04
# Epoch 42/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8845 - loss: 0.2413 - val_accuracy: 0.8245 - val_loss: 0.4122 - learning_rate: 2.4010e-04
# Epoch 43/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 266ms/step - accuracy: 0.8875 - loss: 0.2367 - val_accuracy: 0.8160 - val_loss: 0.4543 - learning_rate: 2.4010e-04
# Epoch 44/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 263ms/step - accuracy: 0.8888 - loss: 0.2366 - val_accuracy: 0.7859 - val_loss: 0.4650 - learning_rate: 2.4010e-04
# Epoch 45/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8952 - loss: 0.2267 - val_accuracy: 0.8182 - val_loss: 0.4562 - learning_rate: 2.4010e-04
# Epoch 46/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 13s 264ms/step - accuracy: 0.8946 - loss: 0.2281 - val_accuracy: 0.7889 - val_loss: 0.4307 - learning_rate: 2.4010e-04
# Epoch 47/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.8764 - loss: 0.2803 - val_accuracy: 0.8156 - val_loss: 0.4344 - learning_rate: 1.6807e-04
# Epoch 48/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 267ms/step - accuracy: 0.8992 - loss: 0.2183 - val_accuracy: 0.8165 - val_loss: 0.4368 - learning_rate: 1.6807e-04
# Epoch 49/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.9002 - loss: 0.2183 - val_accuracy: 0.8141 - val_loss: 0.4524 - learning_rate: 1.6807e-04
# Epoch 50/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8988 - loss: 0.2262 - val_accuracy: 0.8050 - val_loss: 0.4347 - learning_rate: 1.6807e-04
# Epoch 51/100
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 14s 265ms/step - accuracy: 0.8885 - loss: 0.2491 - val_accuracy: 0.8172 - val_loss: 0.4421 - learning_rate: 1.6807e-04

# %%
from tensorflow.keras.metrics import MeanIoU
from sklearn.metrics import precision_score, recall_score, accuracy_score, jaccard_score
import numpy as np

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    """
    Compute the Dice coefficient (F1-score for segmentation).
    """
    intersection = np.sum(y_true * y_pred)
    return (2. * intersection + smooth) / (np.sum(y_true) + np.sum(y_pred) + smooth)

def evaluate_model(model, X_test, Y_test, threshold=0.5):
    """
    Evaluate a trained model on the test dataset using multiple metrics.
    
    Parameters:
        model (tf.keras.Model): Trained segmentation model.
        X_test (numpy array): Test images.
        Y_test (numpy array): Ground truth masks.
        threshold (float): Threshold for binary mask conversion.

    Returns:
        dict: Dictionary containing all metric scores.
    """
    # Predict segmentation masks
    Y_pred = model.predict(X_test, batch_size=8)
    
    # Convert probabilities to binary masks (Thresholding)
    Y_pred_binary = (Y_pred > threshold).astype(np.uint8)

    # Flatten arrays for metric calculations
    Y_test_flat = Y_test.flatten()
    Y_pred_flat = Y_pred_binary.flatten()

    # Compute metrics
    accuracy = accuracy_score(Y_test_flat, Y_pred_flat)
    precision = precision_score(Y_test_flat, Y_pred_flat, zero_division=1)
    recall = recall_score(Y_test_flat, Y_pred_flat, zero_division=1)
    jaccard = jaccard_score(Y_test_flat, Y_pred_flat, zero_division=1)
    dice = dice_coefficient(Y_test_flat, Y_pred_flat)

    # Compute IoU (Mean Intersection over Union)
    mean_iou = MeanIoU(num_classes=2)
    mean_iou.update_state(Y_test, Y_pred_binary)
    iou_score = mean_iou.result().numpy()

    # Print and return results
    metrics = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "Jaccard Coefficient (IoU)": jaccard,
        "Dice Coefficient": dice,
        "Mean IoU": iou_score
    }

    print(f"\n===== Model Evaluation Results =====")
    for key, value in metrics.items():
        print(f"{key}: {value:.4f}")

    return metrics

# %%
models = {
    "U-Net": unet_model,
    "ResNet50 U-Net": resnet_unet,
    "MobileNet U-Net": mobilenet_unet,
    "EfficientNet U-Net": efficientnet_unet,
    "DenseNet U-Net": densenet_unet
}

# Evaluate each model on the test set
model_results = {}
for name, model in models.items():
    print(f"\nEvaluating {name} on Test Set...")
    model_results[name] = evaluate_model(model, X_test, Y_test)
# Out:
# Evaluating U-Net on Test Set...
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 11s 113ms/step
#
# ===== Model Evaluation Results =====
# Accuracy: 0.8010
# Precision: 0.8311
# Recall: 0.8627
# Jaccard Coefficient (IoU): 0.7340
# Dice Coefficient: 0.8466
# Mean IoU: 0.6463
#
# Evaluating ResNet50 U-Net on Test Set...
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 12s 113ms/step
#
# ===== Model Evaluation Results =====
# Accuracy: 0.8172
# Precision: 0.8038
# Recall: 0.9430
# Jaccard Coefficient (IoU): 0.7666
# Dice Coefficient: 0.8679
# Mean IoU: 0.6547
#
# Evaluating MobileNet U-Net on Test Set...
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step
#
# ===== Model Evaluation Results =====
# Accuracy: 0.6360
# Precision: 0.6388
# Recall: 0.9857
# Jaccard Coefficient (IoU): 0.6329
# Dice Coefficient: 0.7752
# Mean IoU: 0.3280
#
# Evaluating EfficientNet U-Net on Test Set...
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 148ms/step
#
# ===== Model Evaluation Results =====
# Accuracy: 0.7542
# Precision: 0.7834
# Recall: 0.8485
# Jaccard Coefficient (IoU): 0.6872
# Dice Coefficient: 0.8146
# Mean IoU: 0.5764
#
# Evaluating DenseNet U-Net on Test Set...
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 27s 259ms/step
#
# ===== Model Evaluation Results =====
# Accuracy: 0.8216
# Precision: 0.8160
# Recall: 0.9293
# Jaccard Coefficient (IoU): 0.7683
# Dice Coefficient: 0.8689
# Mean IoU: 0.6658
